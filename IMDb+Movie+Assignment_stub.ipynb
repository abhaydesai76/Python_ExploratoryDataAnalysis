# %%
# Filtering out the warnings

import warnings

warnings.filterwarnings('ignore')

# %%
# Importing the required libraries

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # <font color = blue> IMDb Movie Assignment </font>
#
# You have the data for the 100 top-rated movies from the past decade along with various pieces of information about the movie, its actors, and the voters who have rated these movies online. In this assignment, you will try to find some interesting insights into these movies and their voters, using Python.

# %% [markdown]
# ##  Task 1: Reading the data

# %% [markdown]
# - ### Subtask 1.1: Read the Movies Data.
#
# Read the movies data file provided and store it in a dataframe `movies`.

# %%
# Read the csv file using 'read_csv'. Please write your dataset location here.
movie_data = pd.read_csv("C:\\upGrad_DataScience\\IMDB_Assignment\\Movie+Assignment+Data.csv")
movie_data.head(10)
# Out:
#                         Title  title_year     budget      Gross  \
# 0                  La La Land        2016   30000000  151101803
# 1                    Zootopia        2016  150000000  341268248
# 2                        Lion        2016   12000000   51738905
# 3                     Arrival        2016   47000000  100546139
# 4       Manchester by the Sea        2016    9000000   47695371
# 5          Hell or High Water        2016   12000000   27007844
# 6              Doctor Strange        2016  165000000  232641920
# 7                     Tangled        2010  260000000  200807262
# 8       The Dark Knight Rises        2012  250000000  448130642
# 9  Captain America: Civil War        2016  250000000  407197282
#
#            actor_1_name        actor_2_name          actor_3_name  \
# 0          Ryan Gosling          Emma Stone            Amiée Conn
# 1      Ginnifer Goodwin       Jason Bateman            Idris Elba
# ...

# %% [markdown]
# - ###  Subtask 1.2: Inspect the Dataframe
#
# Inspect the dataframe for dimensions, null-values, and summary of different numeric columns.

# %%
# Check the number of rows and columns in the dataframe
movie_data.shape
# Out:
# (100, 62)

# %%
# Check the column-wise info of the dataframe
movie_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
# Check the summary for the numeric columns 
movie_data.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %% [markdown]
# ## Task 2: Data Analysis
#
# Now that we have loaded the dataset and inspected it, we see that most of the data is in place. As of now, no data cleaning is required, so let's start with some data manipulation, analysis, and visualisation to get various insights about the data.

# %% [markdown]
# -  ###  Subtask 2.1: Reduce those Digits!
#
# These numbers in the `budget` and `gross` are too big, compromising its readability. Let's convert the unit of the `budget` and `gross` columns from `$` to `million $` first.

# %%
# Divide the 'gross' and 'budget' columns by 1000000 to convert '$' to 'million $'
movie_data["gross million $"] = movie_data["Gross"]/1000000
movie_data["budget million $"] = movie_data["budget"]/1000000

# %%
# Check Dataframe after adding 2 new columns to verify whether data is correctly captured or not
movie_data.head(10)
# Out:
#                         Title  title_year     budget      Gross  \
# 0                  La La Land        2016   30000000  151101803
# 1                    Zootopia        2016  150000000  341268248
# 2                        Lion        2016   12000000   51738905
# 3                     Arrival        2016   47000000  100546139
# 4       Manchester by the Sea        2016    9000000   47695371
# 5          Hell or High Water        2016   12000000   27007844
# 6              Doctor Strange        2016  165000000  232641920
# 7                     Tangled        2010  260000000  200807262
# 8       The Dark Knight Rises        2012  250000000  448130642
# 9  Captain America: Civil War        2016  250000000  407197282
#
#            actor_1_name        actor_2_name          actor_3_name  \
# 0          Ryan Gosling          Emma Stone            Amiée Conn
# 1      Ginnifer Goodwin       Jason Bateman            Idris Elba
# ...

# %%
# drop original columns "Gross" and "budget" as dataframe is having 2 new columns with millions
movie_data.drop("Gross", axis=1, inplace=True)
movie_data.drop("budget", axis=1, inplace=True)

# %% [markdown]
# -  ###  Subtask 2.2: Let's Talk Profit!
#
#     1. Create a new column called `profit` which contains the difference of the two columns: `gross` and `budget`.
#     2. Sort the dataframe using the `profit` column as reference.
#     3. Extract the top ten profiting movies in descending order and store them in a new dataframe - `top10`.
#     4. Plot a scatter or a joint plot between the columns `budget` and `profit` and write a few words on what you observed.
#     5. Extract the movies with a negative profit and store them in a new dataframe - `neg_profit`

# %%
# Create the new column named 'profit' by subtracting the 'budget' column from the 'gross' column
movie_data["profit million $"] = movie_data["gross million $"] - movie_data["budget million $"]
movie_data.head(10)
# Out:
#                         Title  title_year          actor_1_name  \
# 0                  La La Land        2016          Ryan Gosling
# 1                    Zootopia        2016      Ginnifer Goodwin
# 2                        Lion        2016             Dev Patel
# 3                     Arrival        2016             Amy Adams
# 4       Manchester by the Sea        2016         Casey Affleck
# 5          Hell or High Water        2016            Chris Pine
# 6              Doctor Strange        2016  Benedict Cumberbatch
# 7                     Tangled        2010          Brad Garrett
# 8       The Dark Knight Rises        2012             Tom Hardy
# 9  Captain America: Civil War        2016     Robert Downey Jr.
#
#          actor_2_name          actor_3_name  actor_1_facebook_likes  \
# 0          Emma Stone            Amiée Conn                   14000
# 1       Jason Bateman            Idris Elba                    2800
# ...

# %%
# Sort the dataframe with the 'profit' column as reference using the 'sort_values' function. Make sure to set the argument
#'ascending' to 'False'
movie_data = movie_data.sort_values(by="profit million $", ascending=False)
movie_data.head(10)
# Out:
#                                          Title  title_year       actor_1_name  \
# 97  Star Wars: Episode VII - The Force Awakens        2015        Doug Walker
# 11                                The Avengers        2012    Chris Hemsworth
# 47                                    Deadpool        2016      Ryan Reynolds
# 32             The Hunger Games: Catching Fire        2013  Jennifer Lawrence
# 12                                 Toy Story 3        2010          Tom Hanks
# 8                        The Dark Knight Rises        2012          Tom Hardy
# 45                              The Lego Movie        2014     Morgan Freeman
# 1                                     Zootopia        2016   Ginnifer Goodwin
# 41                               Despicable Me        2010       Steve Carell
# 18                                  Inside Out        2015        Amy Poehler
#
#          actor_2_name           actor_3_name  actor_1_facebook_likes  \
# ...

# %%
# Get the top 10 profitable movies by using position based indexing. Specify the rows till 10 (0-9)
top10 = movie_data.sort_values(by="profit million $", ascending=False).iloc[:10,:]
top10
# Out:
#                                          Title  title_year       actor_1_name  \
# 97  Star Wars: Episode VII - The Force Awakens        2015        Doug Walker
# 11                                The Avengers        2012    Chris Hemsworth
# 47                                    Deadpool        2016      Ryan Reynolds
# 32             The Hunger Games: Catching Fire        2013  Jennifer Lawrence
# 12                                 Toy Story 3        2010          Tom Hanks
# 8                        The Dark Knight Rises        2012          Tom Hardy
# 45                              The Lego Movie        2014     Morgan Freeman
# 1                                     Zootopia        2016   Ginnifer Goodwin
# 41                               Despicable Me        2010       Steve Carell
# 18                                  Inside Out        2015        Amy Poehler
#
#          actor_2_name           actor_3_name  actor_1_facebook_likes  \
# ...

# %%
#Plot profit vs budget
N = 100
plt.figure(figsize=[10,8])
colors = np.random.rand(N)
plt.scatter(data=movie_data,x="profit million $", y="budget million $", c=colors, label="Movie Profit")
plt.xlabel("Movie Profit million $")
plt.ylabel("Movie Budget million $")
plt.legend(loc="upper right")
plt.show()

# %%
# Scatter plot above shows that there is a relation between movie budget and movie profit, but it is not linear or 
# straight line, means it is not like that only higher budget is a guarantee of higher profit. There are movies having 
# low budget and earning good profit, like movie "Deadpool" having budget of $ 58 million and generating profit of 
# $ 305 million, while movie "The Hunger Games: Catching Fire" is having budget of $ 130 million and generating profit of 
# $ 294 million.
# Also, top 10 movies with highest profit are released after year 2010 which can be concluded that there are multiple avenues 
# for movies to generate more business other than only cinemas like satellite rights, online streaming platforms etc.
# Another observation is, if we look at actor1, actor2 and actor3 for these top 10 movies, there is hardly an actor, who has
# starred in multiple movies, which means movie profit is not dependent on any specific actor.
# In addition, all top 10 movies belong to only 2 genre named "Animation" and "Action".
# There are some movies which are showing negative profit. We need to find out what is the real reason for generating negative 
# profit.

# %% [markdown]
# The dataset contains the 100 best performing movies from the year 2010 to 2016. However, the scatter plot tells a different story. You can notice that there are some movies with negative profit. Although good movies do incur losses, but there appear to be quite a few movie with losses. What can be the reason behind this? Lets have a closer look at this by finding the movies with negative profit.

# %%
#Find the movies with negative profit
neg_profit = movie_data[movie_data["profit million $"] < 0]
neg_profit
# Out:
#                           Title  title_year         actor_1_name  \
# 99      Tucker and Dale vs Evil        2010       Katrina Bowden
# 89                        Amour        2012     Isabelle Huppert
# 56                         Rush        2013      Chris Hemsworth
# 66                      Warrior        2011            Tom Hardy
# 82                      Flipped        2010     Madeline Carroll
# 28           X-Men: First Class        2011    Jennifer Lawrence
# 46  Scott Pilgrim vs. the World        2010        Anna Kendrick
# 7                       Tangled        2010         Brad Garrett
# 17             Edge of Tomorrow        2014           Tom Cruise
# 39            The Little Prince        2015         Jeff Bridges
# 22                         Hugo        2011  ChloÃ« Grace Moretz
#
#           actor_2_name            actor_3_name  actor_1_facebook_likes  \
# 99        Tyler Labine          Chelan Simmons                     948
# ...

# %% [markdown]
# **`Checkpoint 1:`** Can you spot the movie `Tangled` in the dataset? You may be aware of the movie 'Tangled'. Although its one of the highest grossing movies of all time, it has negative profit as per this result. If you cross check the gross values of this movie (link: https://www.imdb.com/title/tt0398286/), you can see that the gross in the dataset accounts only for the domestic gross and not the worldwide gross. This is true for may other movies also in the list.

# %% [markdown]
# - ### Subtask 2.3: The General Audience and the Critics
#
# You might have noticed the column `MetaCritic` in this dataset. This is a very popular website where an average score is determined through the scores given by the top-rated critics. Second, you also have another column `IMDb_rating` which tells you the IMDb rating of a movie. This rating is determined by taking the average of hundred-thousands of ratings from the general audience.
#
# As a part of this subtask, you are required to find out the highest rated movies which have been liked by critics and audiences alike.
# 1. Firstly you will notice that the `MetaCritic` score is on a scale of `100` whereas the `IMDb_rating` is on a scale of 10. First convert the `MetaCritic` column to a scale of 10.
# 2. Now, to find out the movies which have been liked by both critics and audiences alike and also have a high rating overall, you need to -
#     - Create a new column `Avg_rating` which will have the average of the `MetaCritic` and `Rating` columns
#     - Retain only the movies in which the absolute difference(using abs() function) between the `IMDb_rating` and `Metacritic` columns is less than 0.5. Refer to this link to know how abs() funtion works - https://www.geeksforgeeks.org/abs-in-python/ .
#     - Sort these values in a descending order of `Avg_rating` and retain only the movies with a rating equal to or greater than `8` and store these movies in a new dataframe `UniversalAcclaim`.

# %%
# Change the scale of MetaCritic
movie_data["MetaCritic"] = movie_data["MetaCritic"] / 10

# %%
# Find the average ratings
movie_data["Avg_Rating"] = (movie_data["MetaCritic"] + movie_data["IMDb_rating"]) / 2

# %%
movie_data[["Title", "MetaCritic", "IMDb_rating", "Avg_Rating"]]
# Out:
#                                          Title  MetaCritic  IMDb_rating  \
# 97  Star Wars: Episode VII - The Force Awakens         8.1          8.1
# 11                                The Avengers         6.9          8.1
# 47                                    Deadpool         6.5          8.0
# 32             The Hunger Games: Catching Fire         7.6          7.6
# 12                                 Toy Story 3         9.2          8.3
# ..                                         ...         ...          ...
# 46                 Scott Pilgrim vs. the World         6.9          7.5
# 7                                      Tangled         7.1          7.8
# 17                            Edge of Tomorrow         7.1          7.9
# 39                           The Little Prince         7.0          7.8
# 22                                        Hugo         8.3          7.5
#
#     Avg_Rating
# 97        8.10
# 11        7.50
# 47        7.25
# 32        7.60
# 12        8.75
# ...

# %%
abs_diff_movie = movie_data.where(abs(movie_data["IMDb_rating"] - movie_data["MetaCritic"]) < 0.5)
abs_diff_movie = abs_diff_movie.dropna()
abs_diff_movie
# Out:
#                                          Title  title_year       actor_1_name  \
# 97  Star Wars: Episode VII - The Force Awakens      2015.0        Doug Walker
# 32             The Hunger Games: Catching Fire      2013.0  Jennifer Lawrence
# 1                                     Zootopia      2016.0   Ginnifer Goodwin
# 9                   Captain America: Civil War      2016.0  Robert Downey Jr.
# 55                                   True Grit      2010.0         Matt Damon
# 33                                 The Martian      2015.0         Matt Damon
# 68                     Silver Linings Playbook      2012.0  Jennifer Lawrence
# 43                                   Gone Girl      2014.0      Patrick Fugit
# 13                                     Skyfall      2012.0      Albert Finney
# 64                                 The Fighter      2010.0     Christian Bale
# 23                                  Big Hero 6      2014.0   Damon Wayans Jr.
# ...

# %%
#Sort in descending order of average rating
abs_diff_movie.sort_values(by="Avg_Rating", ascending=False)
# Out:
#                                          Title  title_year       actor_1_name  \
# 97  Star Wars: Episode VII - The Force Awakens      2015.0        Doug Walker
# 33                                 The Martian      2015.0         Matt Damon
# 43                                   Gone Girl      2014.0      Patrick Fugit
# 13                                     Skyfall      2012.0      Albert Finney
# 1                                     Zootopia      2016.0   Ginnifer Goodwin
# 62                               The Big Short      2015.0       Ryan Gosling
# 68                     Silver Linings Playbook      2012.0  Jennifer Lawrence
# 74                           Midnight in Paris      2011.0        Kurt Fuller
# 64                                 The Fighter      2010.0     Christian Bale
# 31                                The Revenant      2015.0  Leonardo DiCaprio
# 55                                   True Grit      2010.0         Matt Damon
# ...

# %%
# Find the movies with metacritic-Imdb rating < 0.5 and also with an average rating of >= 8 (sorted in descending order)
UniversalAcclaim = abs_diff_movie.loc[(movie_data["Avg_Rating"] >= 8) ]
UniversalAcclaim.sort_values(by="Avg_Rating", ascending=False)
# Out:
#                                          Title  title_year   actor_1_name  \
# 97  Star Wars: Episode VII - The Force Awakens      2015.0    Doug Walker
# 33                                 The Martian      2015.0     Matt Damon
# 43                                   Gone Girl      2014.0  Patrick Fugit
#
#      actor_2_name       actor_3_name  actor_1_facebook_likes  \
# 97     Rob Walker                  0                   131.0
# 33  Donald Glover      Benedict Wong                 13000.0
# 43      Sela Ward  Emily Ratajkowski                   835.0
#
#     actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating    genre_1  \
# 97                    12.0                     0.0          8.1     Action
# 33                   801.0                   372.0          8.0  Adventure
# 43                   812.0                   625.0          8.1      Crime
#
#     ... Votes45AF Votes1000  VotesUS  VotesnUS  content_rating  Country  \
# ...

# %% [markdown]
# **`Checkpoint 2:`** Can you spot a `Star Wars` movie in your final dataset?

# %% [markdown]
# - ### Subtask 2.4: Find the Most Popular Trios - I
#
# You're a producer looking to make a blockbuster movie. There will primarily be three lead roles in your movie and you wish to cast the most popular actors for it. Now, since you don't want to take a risk, you will cast a trio which has already acted in together in a movie before. The metric that you've chosen to check the popularity is the Facebook likes of each of these actors.
#
# The dataframe has three columns to help you out for the same, viz. `actor_1_facebook_likes`, `actor_2_facebook_likes`, and `actor_3_facebook_likes`. Your objective is to find the trios which has the most number of Facebook likes combined. That is, the sum of `actor_1_facebook_likes`, `actor_2_facebook_likes` and `actor_3_facebook_likes` should be maximum.
# Find out the top 5 popular trios, and output their names in a list.

# %%
movie_data["actor_123_likes"] = movie_data["actor_1_facebook_likes"] + movie_data["actor_2_facebook_likes"] + movie_data["actor_3_facebook_likes"]
movie_data[["actor_1_facebook_likes", "actor_2_facebook_likes", "actor_3_facebook_likes", "actor_123_likes"]]
# Out:
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 97                     131                    12.0                     0.0
# 11                   26000                 21000.0                 19000.0
# 47                   16000                   805.0                   361.0
# 32                   34000                 14000.0                   523.0
# 12                   15000                  1000.0                   721.0
# ..                     ...                     ...                     ...
# 46                   10000                  1000.0                   719.0
# 7                      799                   553.0                   284.0
# 17                   10000                   854.0                   509.0
# 39                   12000                 11000.0                  6000.0
# 22                   17000                 16000.0                  1000.0
#
#     actor_123_likes
# 97            143.0
# 11          66000.0
# ...

# %%
# Write your code here
most_poplar_trio = movie_data[["actor_1_facebook_likes", "actor_2_facebook_likes", "actor_3_facebook_likes", "actor_123_likes"]]
movies_max_like = most_poplar_trio.sort_values(by="actor_123_likes", ascending=False).head()
movies_max_like
# Out:
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 2                    33000                 96000.0                  9800.0
# 27                   29000                 27000.0                 23000.0
# 14                   34000                 22000.0                 20000.0
# 4                      518                 71000.0                  3300.0
# 8                    27000                 23000.0                 23000.0
#
#     actor_123_likes
# 2          138800.0
# 27          79000.0
# 14          76000.0
# 4           74818.0
# 8           73000.0

# %%
popular_trio = []

for row in movies_max_like.index:
    popular_trio.append(row)
    
popular_trio
# Out:
# [2, 27, 14, 4, 8]

# %%
popular_actors = pd.DataFrame(movie_data,index = popular_trio, columns = ["Title", "actor_1_name", "actor_2_name", "actor_3_name", "actor_123_likes"])
popular_actors
# Out:
#                          Title       actor_1_name        actor_2_name  \
# 2                         Lion          Dev Patel       Nicole Kidman
# 27                   Inception  Leonardo DiCaprio           Tom Hardy
# 14  X-Men: Days of Future Past  Jennifer Lawrence      Peter Dinklage
# 4        Manchester by the Sea      Casey Affleck  Michelle Williams
# 8        The Dark Knight Rises          Tom Hardy      Christian Bale
#
#             actor_3_name  actor_123_likes
# 2            Rooney Mara         138800.0
# 27  Joseph Gordon-Levitt          79000.0
# 14          Hugh Jackman          76000.0
# 4          Kyle Chandler          74818.0
# 8   Joseph Gordon-Levitt          73000.0

# %% [markdown]
# - ### Subtask 2.5: Find the Most Popular Trios - II
#
# In the previous subtask you found the popular trio based on the total number of facebook likes. Let's add a small condition to it and make sure that all three actors are popular. The condition is **none of the three actors' Facebook likes should be less than half of the other two**. For example, the following is a valid combo:
# - actor_1_facebook_likes: 70000
# - actor_2_facebook_likes: 40000
# - actor_3_facebook_likes: 50000
#
# But the below one is not:
# - actor_1_facebook_likes: 70000
# - actor_2_facebook_likes: 40000
# - actor_3_facebook_likes: 30000
#
# since in this case, `actor_3_facebook_likes` is 30000, which is less than half of `actor_1_facebook_likes`.
#
# Having this condition ensures that you aren't getting any unpopular actor in your trio (since the total likes calculated in the previous question doesn't tell anything about the individual popularities of each actor in the trio.).
#
# You can do a manual inspection of the top 5 popular trios you have found in the previous subtask and check how many of those trios satisfy this condition. Also, which is the most popular trio after applying the condition above? Write your answers in the markdown cell provided below.

# %% [markdown]
# **Write your answers below.**
#
# - **`No. of trios that satisfy the above condition:`** (your answer here)
#
# - **`Most popular trio after applying the condition:`** (your answer here)

# %% [markdown]
# **`Optional:`** Even though you are finding this out by a natural inspection of the dataframe, can you also achieve this through some *if-else* statements to incorporate this. You can try this out on your own time after you are done with the assignment.

# %%
# Your answer here (optional and not graded)

# Answer 1: There are 3 movies, 27, 14 and 8, having 3 popualr actors having considerable number of likes.
#
#        Title                      actor_1_name        actor_2_name    actor_3_name          actor_123_likes
# 27     Inception                  Leonardo DiCaprio   Tom Hardy       Joseph Gordon-Levitt  79000.0
# 14     X-Men: Days of Future Past Jennifer Lawrence   Peter Dinklage  Hugh Jackman          76000.0
# 8      The Dark Knight Rises      Tom Hardy           Christian Bale  Joseph Gordon-Levitt  73000.0

# Answer 2: "Leonardo DiCaprio", "Tom Hardy" and "Joseph Gordon-Levitt" having total likes as 79000.0 and individual likes
#            as 29000, 27000 and 23000 respectively.

# %% [markdown]
# - ### Subtask 2.6: Runtime Analysis
#
# There is a column named `Runtime` in the dataframe which primarily shows the length of the movie. It might be intersting to see how this variable this distributed. Plot a `histogram` or `distplot` of seaborn to find the `Runtime` range most of the movies fall into.

# %%
# Runtime histogram/density plot
plt.figure(figsize=[8,6])
movie_data["Runtime"].plot.hist()
plt.xlabel("Movie Runtime in Minutes")
plt.ylabel("No of Movies")
plt.show()

# %% [markdown]
# **`Checkpoint 3:`** Most of the movies appear to be sharply 2 hour-long.

# %% [markdown]
# - ### Subtask 2.7: R-Rated Movies
#
# Although R rated movies are restricted movies for the under 18 age group, still there are vote counts from that age group. Among all the R rated movies that have been voted by the under-18 age group, find the top 10 movies that have the highest number of votes i.e.`CVotesU18` from the `movies` dataframe. Store these in a dataframe named `PopularR`.

# %%
# Write your code here
R_Rated_Movies = movie_data[movie_data["content_rating"] == "R"]
PopularR = R_Rated_Movies.sort_values(by="CVotesU18", ascending=False)
PopularR[["Title", "CVotesU18", "actor_1_name", "actor_2_name", "actor_3_name"]].head(10)
# Out:
#                                               Title  CVotesU18  \
# 47                                         Deadpool       4598
# 36                          The Wolf of Wall Street       3622
# 35                                 Django Unchained       3250
# 29                               Mad Max: Fury Road       3159
# 95                                         Whiplash       2878
# 31                                     The Revenant       2619
# 40                                   Shutter Island       2321
# 43                                        Gone Girl       2286
# 65                         The Grand Budapest Hotel       2083
# 72  Birdman or (The Unexpected Virtue of Ignorance)       1891
#
#          actor_1_name         actor_2_name       actor_3_name
# 47      Ryan Reynolds            Ed Skrein     Stefan Kapicic
# 36  Leonardo DiCaprio  Matthew McConaughey        Jon Favreau
# 35  Leonardo DiCaprio      Christoph Waltz       Ato Essandoh
# ...

# %% [markdown]
# **`Checkpoint 4:`** Are these kids watching `Deadpool` a lot?

# %% [markdown]
# ## Task 3 : Demographic analysis
#
# If you take a look at the last columns in the dataframe, most of these are related to demographics of the voters (in the last subtask, i.e., 2.8, you made use one of these columns - CVotesU18). We also have three genre columns indicating the genres of a particular movie. We will extensively use these columns for the third and the final stage of our assignment wherein we will analyse the voters across all demographics and also see how these vary across various genres. So without further ado, let's get started with `demographic analysis`.

# %% [markdown]
# -  ###  Subtask 3.1 Combine the Dataframe by Genres
#
# There are 3 columns in the dataframe - `genre_1`, `genre_2`, and `genre_3`. As a part of this subtask, you need to aggregate a few values over these 3 columns.
# 1. First create a new dataframe `df_by_genre` that contains `genre_1`, `genre_2`, and `genre_3` and all the columns related to **CVotes/Votes** from the `movies` data frame. There are 47 columns to be extracted in total.
# 2. Now, Add a column called `cnt` to the dataframe `df_by_genre` and initialize it to one. You will realise the use of this column by the end of this subtask.
# 3. First group the dataframe `df_by_genre` by `genre_1` and find the sum of all the numeric columns such as `cnt`, columns related to CVotes and Votes columns and store it in a dataframe `df_by_g1`.
# 4. Perform the same operation for `genre_2` and `genre_3` and store it dataframes `df_by_g2` and `df_by_g3` respectively.
# 5. Now that you have 3 dataframes performed by grouping over `genre_1`, `genre_2`, and `genre_3` separately, it's time to combine them. For this, add the three dataframes and store it in a new dataframe `df_add`, so that the corresponding values of Votes/CVotes get added for each genre.There is a function called `add()` in pandas which lets you do this. You can refer to this link to see how this function works. https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.add.html
# 6. The column `cnt` on aggregation has basically kept the track of the number of occurences of each genre.Subset the genres that have atleast 10 movies into a new dataframe `genre_top10` based on the `cnt` column value.
# 7. Now, take the mean of all the numeric columns by dividing them with the column value `cnt` and store it back to the same dataframe. We will be using this dataframe for further analysis in this task unless it is explicitly mentioned to use the dataframe `movies`.
# 8. Since the number of votes can't be a fraction, type cast all the CVotes related columns to integers. Also, round off all the Votes related columns upto two digits after the decimal point.

# %%
# Create the dataframe df_by_genre
df_by_genre = pd.DataFrame(movie_data, columns=["genre_1","genre_2","genre_3", "CVotes10", "CVotes09", "CVotes08",
                                                    "CVotes07", "CVotes06", "CVotes05",
                                                    "CVotes04", "CVotes03", "Cvotes02",
                                                    "CVotes01", "CVotesMale", "CVotesFemale",
                                                    "CVotesU18", "CVotesU18M", "CVotesU18F",
                                                    "CVotes1829", "CVotes1829M", "CVotes1829F",
                                                    "CVotes3044","CVotes3044M","CVotes3044F",
                                                    "CVotes45A","CVotes45AM","CVotes45AF",
                                                    "CVotes1000","CVotesUS","CVotesnUS",
                                                    "VotesM", "VotesF", "VotesU18",
                                                    "VotesU18M", "VotesU18F","Votes1829","Votes1829M",
                                                    "Votes1829F","Votes3044","Votes3044M","Votes3044F",
                                                    "Votes45A","Votes45AM","Votes45AF","Votes1000",
                                                    "VotesUS","VotesnUS"])
df_by_genre
# Out:
#       genre_1    genre_2  genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 97     Action  Adventure  Fantasy    155391    161810    166378     99402
# 11     Action     Sci-Fi      NaN    260257    234203    264290    162604
# 47     Action  Adventure   Comedy    147467    147966    170810    105717
# 32     Action  Adventure  Mystery     85219     83874    150153    121748
# 12  Animation  Adventure   Comedy    139773    149992    158704     88289
# ..        ...        ...      ...       ...       ...       ...       ...
# 46     Action     Comedy  Romance     47292     48976     79198     59689
# 7   Animation  Adventure   Comedy     56575     54688     97207     70947
# 17     Action  Adventure   Sci-Fi     60383     99596    175961    100724
# 39  Animation  Adventure    Drama      7565      7321     11668      8558
# 22  Adventure      Drama   Family     29228     40728     77893     62936
#
#     CVotes06  CVotes05  CVotes04  ...  Votes1829F  Votes3044  Votes3044M  \
# ...

# %%
# Create a column cnt and initialize it to 1
df_by_genre["cnt"] = 1

# %%
# Group the movies by individual genres
df_by_g1 = df_by_genre.groupby("genre_1")["cnt", "CVotes10", "CVotes09", "CVotes08",
                                                    "CVotes07", "CVotes06", "CVotes05",
                                                    "CVotes04", "CVotes03", "Cvotes02",
                                                    "CVotes01", "CVotesMale", "CVotesFemale",
                                                    "CVotesU18", "CVotesU18M", "CVotesU18F",
                                                    "CVotes1829", "CVotes1829M", "CVotes1829F",
                                                    "CVotes3044","CVotes3044M","CVotes3044F",
                                                    "CVotes45A","CVotes45AM","CVotes45AF",
                                                    "CVotes1000","CVotesUS","CVotesnUS",
                                                    "VotesM", "VotesF", "VotesU18",
                                                    "VotesU18M", "VotesU18F","Votes1829","Votes1829M",
                                                    "Votes1829F","Votes3044","Votes3044M","Votes3044F",
                                                    "Votes45A","Votes45AM","Votes45AF","Votes1000",
                                                    "VotesUS","VotesnUS"].sum()
df_by_g1
# Out:
#            cnt  CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      27   2928407   3261919   4247693   2662020    986774    364234
# Adventure   12   1058779   1179818   1560541    966275    365486    136985
# Animation   11    681562    798227   1153214    722782    251076     83069
# Biography   13    666831   1088430   1654704    962977    306247    100005
# Comedy       9    371217    496905    770395    518566    205434     81933
# Crime        9    383290    690221   1083469    627593    206756     71460
# Drama       18   1080725   1494053   1827363   1078966    417205    163874
# Mystery      1    150405    230844    278844    132349     45167     15615
#
#            CVotes04  CVotes03  Cvotes02  ...  Votes1829F  Votes3044  \
# genre_1                                  ...
# Action       156150     89483       0.0  ...       215.3      209.1
# Adventure     58559     33174       0.0  ...        96.4       92.7
# ...

# %%
# Group the movies by individual genres
df_by_g2 = df_by_genre.groupby("genre_2")["cnt", "CVotes10", "CVotes09", "CVotes08",
                                                    "CVotes07", "CVotes06", "CVotes05",
                                                    "CVotes04", "CVotes03", "Cvotes02",
                                                    "CVotes01", "CVotesMale", "CVotesFemale",
                                                    "CVotesU18", "CVotesU18M", "CVotesU18F",
                                                    "CVotes1829", "CVotes1829M", "CVotes1829F",
                                                    "CVotes3044","CVotes3044M","CVotes3044F",
                                                    "CVotes45A","CVotes45AM","CVotes45AF",
                                                    "CVotes1000","CVotesUS","CVotesnUS",
                                                    "VotesM", "VotesF", "VotesU18",
                                                    "VotesU18M", "VotesU18F","Votes1829","Votes1829M",
                                                    "Votes1829F","Votes3044","Votes3044M","Votes3044F",
                                                    "Votes45A","Votes45AM","Votes45AF","Votes1000",
                                                    "VotesUS","VotesnUS"].sum()
df_by_g2
# Out:
#            cnt  CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_2
# Action       4    238060    285510    430062    260106     88580     29250
# Adventure   22   2297820   2548864   3271725   2055600    758009    272735
# Biography    5    185172    313178    576374    370003    119348     38643
# Comedy       7    428995    624720    854162    512668    193916     76752
# Crime        1     19576     40247     85359     64633     24920      8548
# Drama       35   1923492   2761237   4112363   2492241    853434    300100
# Family       1     68937     54947    102488     80465     31205     11792
# Fantasy      3    270616    290831    447307    291071    120920     47215
# History      1     15757     32840     83322     63800     19183      5178
# Horror       1     16572     19818     44460     35863     13456      4588
# Music        1    110404    161864    132656     56007     16577      6031
# ...

# %%
# Group the movies by individual genres
df_by_g3 = df_by_genre.groupby("genre_3")["cnt", "CVotes10", "CVotes09", "CVotes08",
                                                    "CVotes07", "CVotes06", "CVotes05",
                                                    "CVotes04", "CVotes03", "Cvotes02",
                                                    "CVotes01", "CVotesMale", "CVotesFemale",
                                                    "CVotesU18", "CVotesU18M", "CVotesU18F",
                                                    "CVotes1829", "CVotes1829M", "CVotes1829F",
                                                    "CVotes3044","CVotes3044M","CVotes3044F",
                                                    "CVotes45A","CVotes45AM","CVotes45AF",
                                                    "CVotes1000","CVotesUS","CVotesnUS",
                                                    "VotesM", "VotesF", "VotesU18",
                                                    "VotesU18M", "VotesU18F","Votes1829","Votes1829M",
                                                    "Votes1829F","Votes3044","Votes3044M","Votes3044F",
                                                    "Votes45A","Votes45AM","Votes45AF","Votes1000",
                                                    "VotesUS","VotesnUS"].sum()
df_by_g3
# Out:
#            cnt  CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_3
# Adventure    4    238060    285510    430062    260106     88580     29250
# Comedy       7    583404    653362    882294    559835    200937     68167
# Crime        1    171660    236650    250667    129164     46715     18682
# Drama       12    400221    680085   1167327    748493    258717     88338
# Family       1     29228     40728     77893     62936     27932     11179
# Fantasy      4    301836    311392    442460    308676    120911     46269
# History      3    135504    227547    311209    159262     48678     16055
# Music        1     74245     71191     64640     38831     17377      8044
# Mystery      4    274446    443661    654167    375087    128131     44818
# Romance      8    319534    418790    715954    497486    193588     75675
# Sci-Fi      15   1975041   2169036   2569011   1517219    546668    200825
# ...

# %%
df_by_g12 = df_by_g1.add(df_by_g2, axis=0, fill_value=0, level=0)
df_by_g12
# Out:
#             cnt   CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  \
# Action     31.0  3166467.0  3547429.0  4677755.0  2922126.0  1075354.0
# Adventure  34.0  3356599.0  3728682.0  4832266.0  3021875.0  1123495.0
# Animation  11.0   681562.0   798227.0  1153214.0   722782.0   251076.0
# Biography  18.0   852003.0  1401608.0  2231078.0  1332980.0   425595.0
# Comedy     16.0   800212.0  1121625.0  1624557.0  1031234.0   399350.0
# Crime      10.0   402866.0   730468.0  1168828.0   692226.0   231676.0
# Drama      53.0  3004217.0  4255290.0  5939726.0  3571207.0  1270639.0
# Family      1.0    68937.0    54947.0   102488.0    80465.0    31205.0
# Fantasy     3.0   270616.0   290831.0   447307.0   291071.0   120920.0
# History     1.0    15757.0    32840.0    83322.0    63800.0    19183.0
# Horror      1.0    16572.0    19818.0    44460.0    35863.0    13456.0
# Music       1.0   110404.0   161864.0   132656.0    56007.0    16577.0
# ...

# %%
final_df_by_genre = df_by_g12.add(df_by_g3, axis=0, fill_value=0, level=0)
final_df_by_genre
# Out:
#             cnt   CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  \
# Action     31.0  3166467.0  3547429.0  4677755.0  2922126.0  1075354.0
# Adventure  38.0  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0
# Animation  11.0   681562.0   798227.0  1153214.0   722782.0   251076.0
# Biography  18.0   852003.0  1401608.0  2231078.0  1332980.0   425595.0
# Comedy     23.0  1383616.0  1774987.0  2506851.0  1591069.0   600287.0
# Crime      11.0   574526.0   967118.0  1419495.0   821390.0   278391.0
# Drama      65.0  3404438.0  4935375.0  7107053.0  4319700.0  1529356.0
# Family      2.0    98165.0    95675.0   180381.0   143401.0    59137.0
# Fantasy     7.0   572452.0   602223.0   889767.0   599747.0   241831.0
# History     4.0   151261.0   260387.0   394531.0   223062.0    67861.0
# Horror      1.0    16572.0    19818.0    44460.0    35863.0    13456.0
# Music       2.0   184649.0   233055.0   197296.0    94838.0    33954.0
# ...

# %%
# Extract genres with atleast 10 occurences
genre_top10 = final_df_by_genre[final_df_by_genre["cnt"] >= 10]
genre_top10
# Out:
#             cnt   CVotes10   CVotes09   CVotes08   CVotes07   CVotes06  \
# Action     31.0  3166467.0  3547429.0  4677755.0  2922126.0  1075354.0
# Adventure  38.0  3594659.0  4014192.0  5262328.0  3281981.0  1212075.0
# Animation  11.0   681562.0   798227.0  1153214.0   722782.0   251076.0
# Biography  18.0   852003.0  1401608.0  2231078.0  1332980.0   425595.0
# Comedy     23.0  1383616.0  1774987.0  2506851.0  1591069.0   600287.0
# Crime      11.0   574526.0   967118.0  1419495.0   821390.0   278391.0
# Drama      65.0  3404438.0  4935375.0  7107053.0  4319700.0  1529356.0
# Romance    13.0   549959.0   689492.0  1069280.0   712841.0   281289.0
# Sci-Fi     17.0  2325284.0  2530855.0  3002994.0  1802098.0   671811.0
# Thriller   13.0  1081701.0  1465491.0  1993378.0  1175799.0   416046.0
#
#            CVotes05  CVotes04  CVotes03  Cvotes02  ...  Votes1829F  Votes3044  \
# Action     393484.0  166970.0   95004.0       0.0  ...       248.0      240.0
# ...

# %%
# Take the mean for every column by dividing with cnt 
genre_top10 = genre_top10.div(genre_top10["cnt"], axis=0)
genre_top10
# Out:
#            cnt       CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     1.0  102144.096774  114433.193548  150895.322581   94262.129032
# Adventure  1.0   94596.289474  105636.631579  138482.315789   86367.921053
# Animation  1.0   61960.181818   72566.090909  104837.636364   65707.454545
# Biography  1.0   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy     1.0   60157.217391   77173.347826  108993.521739   69176.913043
# Crime      1.0   52229.636364   87919.818182  129045.000000   74671.818182
# Drama      1.0   52375.969231   75928.846154  109339.276923   66456.923077
# Romance    1.0   42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     1.0  136781.411765  148873.823529  176646.705882  106005.764706
# Thriller   1.0   83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03  Cvotes02  \
# ...

# %%
# Converting CVotes to int type
genre_top10["CVotes10"] = genre_top10["CVotes10"].astype('int32')
genre_top10["CVotes09"] = genre_top10["CVotes09"].astype('int32')
genre_top10["CVotes08"] = genre_top10["CVotes08"].astype('int32')
genre_top10["CVotes07"] = genre_top10["CVotes07"].astype('int32')
genre_top10["CVotes06"] = genre_top10["CVotes06"].astype('int32')
genre_top10["CVotes05"] = genre_top10["CVotes05"].astype('int32')
genre_top10["CVotes04"] = genre_top10["CVotes04"].astype('int32')
genre_top10["CVotes03"] = genre_top10["CVotes03"].astype('int32')
genre_top10["Cvotes02"] = genre_top10["Cvotes02"].astype('int32')
genre_top10["CVotes01"] = genre_top10["CVotes01"].astype('int32')

genre_top10["CVotesMale"] = genre_top10["CVotesMale"].astype('int32')
genre_top10["CVotesFemale"] = genre_top10["CVotesFemale"].astype('int32')
genre_top10["CVotesU18"] = genre_top10["CVotesU18"].astype('int32')
genre_top10["CVotesU18M"] = genre_top10["CVotesU18M"].astype('int32')
genre_top10["CVotesU18F"] = genre_top10["CVotesU18F"].astype('int32')
genre_top10["CVotes1829"] = genre_top10["CVotes1829"].astype('int32')
genre_top10["CVotes1829M"] = genre_top10["CVotes1829M"].astype('int32')
genre_top10["CVotes1829F"] = genre_top10["CVotes1829F"].astype('int32')

genre_top10["CVotes3044"] = genre_top10["CVotes3044"].astype('int32')
genre_top10["CVotes3044M"] = genre_top10["CVotes3044M"].astype('int32')
genre_top10["CVotes3044F"] = genre_top10["CVotes3044F"].astype('int32')
genre_top10["CVotes45A"] = genre_top10["CVotes45A"].astype('int32')
genre_top10["CVotes45AM"] = genre_top10["CVotes45AM"].astype('int32')
genre_top10["CVotes45AF"] = genre_top10["CVotes45AF"].astype('int32')
genre_top10["CVotes1000"] = genre_top10["CVotes1000"].astype('int32')
genre_top10["CVotesUS"] = genre_top10["CVotesUS"].astype('int32')
genre_top10["CVotesnUS"] = genre_top10["CVotesnUS"].astype('int32')

genre_top10
# Out:
#            cnt  CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action     1.0    102144    114433    150895     94262     34688     12693
# Adventure  1.0     94596    105636    138482     86367     31896     11551
# Animation  1.0     61960     72566    104837     65707     22825      7551
# Biography  1.0     47333     77867    123948     74054     23644      7702
# Comedy     1.0     60157     77173    108993     69176     26099      9863
# Crime      1.0     52229     87919    129045     74671     25308      8971
# Drama      1.0     52375     75928    109339     66456     23528      8497
# Romance    1.0     42304     53037     82252     54833     21637      8530
# Sci-Fi     1.0    136781    148873    176646    106005     39518     14951
# Thriller   1.0     83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  Cvotes02  ...  Votes1829F  Votes3044  \
# Action         5386      3064         0  ...    8.000000   7.741935
# ...

# %%
# Rounding off the columns of Votes to two decimals
genre_top10.round(2)
# Out:
#            cnt  CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Action     1.0    102144    114433    150895     94262     34688     12693
# Adventure  1.0     94596    105636    138482     86367     31896     11551
# Animation  1.0     61960     72566    104837     65707     22825      7551
# Biography  1.0     47333     77867    123948     74054     23644      7702
# Comedy     1.0     60157     77173    108993     69176     26099      9863
# Crime      1.0     52229     87919    129045     74671     25308      8971
# Drama      1.0     52375     75928    109339     66456     23528      8497
# Romance    1.0     42304     53037     82252     54833     21637      8530
# Sci-Fi     1.0    136781    148873    176646    106005     39518     14951
# Thriller   1.0     83207    112730    153336     90446     32003     11534
#
#            CVotes04  CVotes03  Cvotes02  ...  Votes1829F  Votes3044  \
# Action         5386      3064         0  ...        8.00       7.74
# ...

# %% [markdown]
# If you take a look at the final dataframe that you have gotten, you will see that you now have the complete information about all the demographic (Votes- and CVotes-related) columns across the top 10 genres. We can use this dataset to extract exciting insights about the voters!

# %% [markdown]
# -  ###  Subtask 3.2: Genre Counts!
#
# Now let's derive some insights from this data frame. Make a bar chart plotting different genres vs cnt using seaborn.

# %%
# Countplot for genres
plt.figure(figsize=[8,6])
sns.barplot(data = final_df_by_genre, x = final_df_by_genre.index, y = "cnt")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **`Checkpoint 5:`** Is the bar for `Drama` the tallest?

# %% [markdown]
# -  ###  Subtask 3.3: Gender and Genre
#
# If you have closely looked at the Votes- and CVotes-related columns, you might have noticed the suffixes `F` and `M` indicating Female and Male. Since we have the vote counts for both males and females, across various age groups, let's now see how the popularity of genres vary between the two genders in the dataframe.
#
# 1. Make the first heatmap to see how the average number of votes of males is varying across the genres. Use seaborn heatmap for this analysis. The X-axis should contain the four age-groups for males, i.e., `CVotesU18M`,`CVotes1829M`, `CVotes3044M`, and `CVotes45AM`. The Y-axis will have the genres and the annotation in the heatmap tell the average number of votes for that age-male group.
#
# 2. Make the second heatmap to see how the average number of votes of females is varying across the genres. Use seaborn heatmap for this analysis. The X-axis should contain the four age-groups for females, i.e., `CVotesU18F`,`CVotes1829F`, `CVotes3044F`, and `CVotes45AF`. The Y-axis will have the genres and the annotation in the heatmap tell the average number of votes for that age-female group.
#
# 3. Make sure that you plot these heatmaps side by side using `subplots` so that you can easily compare the two genders and derive insights.
#
# 4. Write your any three inferences from this plot. You can make use of the previous bar plot also here for better insights.
# Refer to this link- https://seaborn.pydata.org/generated/seaborn.heatmap.html. You might have to plot something similar to the fifth chart in this page (You have to plot two such heatmaps side by side).
#
# 5. Repeat subtasks 1 to 4, but now instead of taking the CVotes-related columns, you need to do the same process for the Votes-related columns. These heatmaps will show you how the two genders have rated movies across various genres.
#
# You might need the below link for formatting your heatmap.
# https://stackoverflow.com/questions/56942670/matplotlib-seaborn-first-and-last-row-cut-in-half-of-heatmap-plot
#
# -  Note : Use `genre_top10` dataframe for this subtask

# %%
genre_top10[["CVotesU18M", "CVotes1829M", "CVotes3044M", "CVotes45AM","CVotesU18F", "CVotes1829F", "CVotes3044F", "CVotes45AF"]]
# Out:
#            CVotesU18M  CVotes1829M  CVotes3044M  CVotes45AM  CVotesU18F  \
# Action           1916       164703       132836       24092         525
# Adventure        1900       146808       115795       21910         601
# Animation        1486       103695        75824       12966         664
# Biography         886       114043        92158       18039         265
# Comedy           1178       109016        86346       15979         459
# Crime             932       122690       102671       18799         227
# Drama             915       105203        87644       17422         317
# Romance           535        79024        62253       12054         474
# Sci-Fi           2382       197123       160141       30141         613
# Thriller         1327       156573       129421       24421         322
#
#            CVotes1829F  CVotes3044F  CVotes45AF
# Action           36996        20627        4269
# Adventure        39896        20750        4267
# ...

# %%
# 1st set of heat maps for CVotes-related columns
plt.figure(figsize=[8,6])
sns.heatmap(genre_top10[["CVotesU18M", "CVotes1829M", "CVotes3044M", "CVotes45AM"]], annot=True, fmt="d")
plt.show()

# %%
# 1st set of heat maps for CVotes-related columns
plt.figure(figsize=[8,6])
sns.heatmap(genre_top10[["CVotesU18F", "CVotes1829F", "CVotes3044F", "CVotes45AF"]], annot=True, fmt="d")
plt.show()

# %%
fig, (ax1, ax2)  = plt.subplots(1, 2, figsize=(16, 8))

sns.heatmap(data=genre_top10[["CVotesU18M", "CVotes1829M", "CVotes3044M", "CVotes45AM"]], annot=True, fmt="d", ax=ax1)
sns.heatmap(data=genre_top10[["CVotesU18F", "CVotes1829F", "CVotes3044F", "CVotes45AF"]], annot=True, fmt="d", ax=ax2)

plt.show()

# %% [markdown]
# **`Inferences:`** A few inferences that can be seen from the heatmap above is that males have voted more than females, and Sci-Fi appears to be most popular among the 18-29 age group irrespective of their gender. What more can you infer from the two heatmaps that you have plotted? Write your three inferences/observations below:
# - Inference 1:
# - Inference 2:
# - Inference 3:

# %%
# 4 inferences from above heatmap
# (i) Maximum number of vote has been given by males and females from age group of 18 to 29.
# (ii) Least number of vote has been given by males and females from age group of under 18.
# (iii) "Sci-Fi" is the majorly poluar genre across all age groups amongst male and female.
# (iv) "Romance" and "Biography" are least preferred genre amongst males and "Crime" and "Biography" are
#       least preferred genre amongst females for age group of under 18.

# %%
genre_top10[["VotesU18M", "Votes1829M", "Votes3044M", "Votes45AM", "VotesU18F", "Votes1829F", "Votes3044F", "Votes45AF"]]
# Out:
#            VotesU18M  Votes1829M  Votes3044M  Votes45AM  VotesU18F  \
# Action      8.154839    7.983871    7.725806   7.625806   8.283871
# Adventure   8.139474    8.007895    7.728947   7.642105   8.286842
# Animation   7.972727    7.990909    7.718182   7.645455   8.245455
# Biography   8.144444    7.983333    7.716667   7.661111   8.161111
# Comedy      8.126087    7.991304    7.713043   7.595652   8.126087
# Crime       8.263636    8.018182    7.763636   7.618182   7.972727
# Drama       8.187692    7.995385    7.709231   7.620000   8.149231
# Romance     8.061538    7.923077    7.607692   7.500000   8.161538
# Sci-Fi      8.294118    8.111765    7.852941   7.694118   8.329412
# Thriller    8.207692    8.023077    7.746154   7.638462   8.069231
#
#            Votes1829F  Votes3044F  Votes45AF
# Action       8.000000    7.800000   7.754839
# Adventure    8.086842    7.873684   7.842105
# Animation    8.200000    7.981818   7.881818
# Biography    7.933333    7.766667   7.872222
# ...

# %%
# 2nd set of heat maps for Votes-related columns

fig, (ax1, ax2)  = plt.subplots(1, 2, figsize=(16, 8))

sns.heatmap(data=genre_top10[["VotesU18M", "Votes1829M", "Votes3044M", "Votes45AM"]], fmt = ".2f", annot=True, ax=ax1)
sns.heatmap(data=genre_top10[["VotesU18F", "Votes1829F", "Votes3044F", "Votes45AF"]], fmt = ".2f", annot=True, ax=ax2)

plt.show()

# %%
# 5 inferences from above heatmap
# (i) "Crime" and "Sci-Fi" genre are two most popular amongst age group of male under 18.
# (ii) "Action", "Adventure" and "Sci-Fi" genre are most popular amongst age group of female under 18.
# (iii) "Sci-Fi" is popular amongst male of all age groups.
# (iv) People from age group of 45 and above are not giving higher ratings to any genre movies.
# (v) "Animation" genre is majorly favourite across all female age groups.

# %% [markdown]
# **`Inferences:`** Sci-Fi appears to be the highest rated genre in the age group of U18 for both males and females. Also, females in this age group have rated it a bit higher than the males in the same age group. What more can you infer from the two heatmaps that you have plotted? Write your three inferences/observations below:
# - Inference 1:
# - Inference 2:
# - Inference 3:

# %% [markdown]
# -  ###  Subtask 3.4: US vs non-US Cross Analysis
#
# The dataset contains both the US and non-US movies. Let's analyse how both the US and the non-US voters have responded to the US and the non-US movies.
#
# 1. Create a column `IFUS` in the dataframe `movies`. The column `IFUS` should contain the value "USA" if the `Country` of the movie is "USA". For all other countries other than the USA, `IFUS` should contain the value `non-USA`.
#
#
# 2. Now make a boxplot that shows how the number of votes from the US people i.e. `CVotesUS` is varying for the US and non-US movies. Make use of the column `IFUS` to make this plot. Similarly, make another subplot that shows how non US voters have voted for the US and non-US movies by plotting `CVotesnUS` for both the US and non-US movies. Write any of your two inferences/observations from these plots.
#
#
# 3. Again do a similar analysis but with the ratings. Make a boxplot that shows how the ratings from the US people i.e. `VotesUS` is varying for the US and non-US movies. Similarly, make another subplot that shows how `VotesnUS` is varying for the US and non-US movies. Write any of your two inferences/observations from these plots.
#
# Note : Use `movies` dataframe for this subtask. Make use of this documention to format your boxplot - https://seaborn.pydata.org/generated/seaborn.boxplot.html

# %%
# Creating IFUS column
movie_data["IFUS"] = movie_data["Country"].apply(lambda x: "USA" if x == "USA" else "non-USA")

# %%
movie_data.head(10)
# Out:
#                                          Title  title_year       actor_1_name  \
# 97  Star Wars: Episode VII - The Force Awakens        2015        Doug Walker
# 11                                The Avengers        2012    Chris Hemsworth
# 47                                    Deadpool        2016      Ryan Reynolds
# 32             The Hunger Games: Catching Fire        2013  Jennifer Lawrence
# 12                                 Toy Story 3        2010          Tom Hanks
# 8                        The Dark Knight Rises        2012          Tom Hardy
# 45                              The Lego Movie        2014     Morgan Freeman
# 1                                     Zootopia        2016   Ginnifer Goodwin
# 41                               Despicable Me        2010       Steve Carell
# 18                                  Inside Out        2015        Amy Poehler
#
#          actor_2_name           actor_3_name  actor_1_facebook_likes  \
# ...

# %%
# Box plot - 1: CVotesUS(y) vs IFUS(x)
fig, (ax1, ax2)  = plt.subplots(1, 2, figsize=(16, 8))

sns.boxplot(x = movie_data["IFUS"], y = movie_data["CVotesUS"], ax = ax1)
sns.boxplot(x = movie_data["IFUS"], y = movie_data["CVotesnUS"], ax = ax2)

plt.show()

# %%
movie_data[["IFUS", "CVotesUS", "CVotesnUS"]]
# Out:
#        IFUS  CVotesUS  CVotesnUS
# 97      USA     85141     250769
# 11      USA    145826     423958
# 47      USA     67933     241138
# 32      USA     68521     221430
# 12      USA    105490     267692
# ..      ...       ...        ...
# 46      USA     56559     150511
# 7       USA     47643     148024
# 17      USA     55486     217557
# 39  non-USA      3678      19009
# 22      USA     39127     142850
#
# [100 rows x 3 columns]

# %%
movie_data[["CVotesUS", "CVotesnUS"]].describe()
# Out:
#             CVotesUS      CVotesnUS
# count     100.000000     100.000000
# mean    54096.740000  188245.680000
# std     32115.288162  106902.256347
# min      3678.000000   19009.000000
# 25%     33328.750000  121863.500000
# 50%     48560.000000  169132.000000
# 75%     70167.000000  239628.250000
# max    212524.000000  707266.000000

# %%
# 3 inferences from above boxplot
# (i) Normally non-USA people vote for both USA and Non-USA movies alike, while USA people vote more for movies produced in USA.
# (ii) There are outliers for both USA and Non-USA movies and IQR is more for Non-USA votes than USA votes.
# (iii) The votes given by USA people are in a smaller range compared to vote range of Non-USA people.

# %% [markdown]
# **`Inferences:`** Write your two inferences/observations below:
# - Inference 1:
# - Inference 2:

# %%
# Box plot - 2: VotesUS(y) vs IFUS(x)

fig, (ax1, ax2)  = plt.subplots(1, 2, figsize=(16, 8))

sns.boxplot(x = movie_data["IFUS"], y = movie_data["VotesUS"], ax = ax1)
sns.boxplot(x = movie_data["IFUS"], y = movie_data["VotesnUS"], ax = ax2)

plt.show()

# %%
movie_data[["IFUS", "VotesUS", "VotesnUS"]]
# Out:
#        IFUS  VotesUS  VotesnUS
# 97      USA      8.2       7.9
# 11      USA      8.3       7.9
# 47      USA      8.1       7.9
# 32      USA      7.7       7.4
# 12      USA      8.5       8.3
# ..      ...      ...       ...
# 46      USA      7.8       7.4
# 7       USA      7.9       7.7
# 17      USA      8.0       7.8
# 39  non-USA      7.7       7.7
# 22      USA      7.7       7.5
#
# [100 rows x 3 columns]

# %%
movie_data[["VotesUS", "VotesnUS"]].describe()
# Out:
#           VotesUS    VotesnUS
# count  100.000000  100.000000
# mean     7.958000    7.793000
# std      0.232327    0.264099
# min      7.500000    7.300000
# 25%      7.800000    7.600000
# 50%      7.950000    7.750000
# 75%      8.100000    7.925000
# max      8.700000    8.800000

# %%
# 2 inferences from above boxplot
# (i) Normally USA people give rating in range of 7.8 to 8.1 for USA based movies with highest rating as 8.5, while Non-USA 
#     people give rating in range of 7.6 to 7.9 for USA based movies with highest rating as 8.3.
# (ii) Majority of Non-USA people give good rating to Non-USA movies compared to USA movies.

# %% [markdown]
# **`Inferences:`** Write your two inferences/observations below:
# - Inference 1:
# - Inference 2:

# %% [markdown]
# -  ###  Subtask 3.5:  Top 1000 Voters Vs Genres
#
# You might have also observed the column `CVotes1000`. This column represents the top 1000 voters on IMDb and gives the count for the number of these voters who have voted for a particular movie. Let's see how these top 1000 voters have voted across the genres.
#
# 1. Sort the dataframe genre_top10 based on the value of `CVotes1000`in a descending order.
#
# 2. Make a seaborn barplot for `genre` vs `CVotes1000`.
#
# 3. Write your inferences. You can also try to relate it with the heatmaps you did in the previous subtasks.

# %%
# Sorting by CVotes1000

genre_top10.sort_values(by="CVotes1000", ascending=False)
# Out:
#            cnt  CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# Sci-Fi     1.0    136781    148873    176646    106005     39518     14951
# Action     1.0    102144    114433    150895     94262     34688     12693
# Thriller   1.0     83207    112730    153336     90446     32003     11534
# Adventure  1.0     94596    105636    138482     86367     31896     11551
# Crime      1.0     52229     87919    129045     74671     25308      8971
# Comedy     1.0     60157     77173    108993     69176     26099      9863
# Biography  1.0     47333     77867    123948     74054     23644      7702
# Drama      1.0     52375     75928    109339     66456     23528      8497
# Animation  1.0     61960     72566    104837     65707     22825      7551
# Romance    1.0     42304     53037     82252     54833     21637      8530
#
#            CVotes04  CVotes03  Cvotes02  ...  Votes1829F  Votes3044  \
# Sci-Fi         6583      3876         0  ...    8.041176   7.858824
# ...

# %%
genre_top10["CVotes1000"].describe()
# Out:
# count     10.000000
# mean     626.200000
# std       52.847369
# min      548.000000
# 25%      588.750000
# 50%      612.500000
# 75%      667.250000
# max      714.000000
# Name: CVotes1000, dtype: float64

# %%
genre_top10.groupby(by=genre_top10.index)["CVotes1000"].sum()
# Out:
# Action       681
# Adventure    662
# Animation    578
# Biography    600
# Comedy       605
# Crime        620
# Drama        585
# Romance      548
# Sci-Fi       714
# Thriller     669
# Name: CVotes1000, dtype: int32

# %%
# Bar plot
plt.figure(figsize=[8,6])
sns.barplot(data = genre_top10, x = genre_top10.index, y = "CVotes1000")
plt.xticks(rotation=45)
plt.show()

# %%
# 2 inferences from above boxplot
# (i) The genre "Sci-Fi" is most popular amongst top 1000 IMDB votes, while the genre "Romance" looks most unpopular.
# (ii) There are 3 genres, "Action", "Adventure" and "Thriller, which are equally popular.

# %% [markdown]
# **`Inferences:`** Write your inferences/observations here.

# %% [markdown]
# **`Checkpoint 6:`** The genre `Romance` seems to be most unpopular among the top 1000 voters.

# %% [markdown]
# With the above subtask, your assignment is over. In your free time, do explore the dataset further on your own and see what kind of other insights you can get across various other columns.
